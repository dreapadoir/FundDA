# %% [markdown]
# <h1 style="color: rgb(0, 133, 202);">Information</h1>
#
# <hr style="border-top: 1px solid rgb(0, 0, 0);" />

# %% [markdown]
# <h2 style="color: rgb(0, 133, 202);">Exercise 1</h2>

# %% [markdown]
# Adapt the code given in the 01-Information Jupyter notebook to generate a 1000 character long string with weights based on the previous two characters. The original code by Ian McLoughlin is referenced [here](https://github.com/ianmcloughlin/2223-S1-fund-data-analysis/blob/main/notebooks/01-information.ipynb).
#
# <hr style="border-top: 1px solid rgb(0, 0, 0);" />

# %% [markdown]
# Get the text of Alice in Wonderland using the request method from the urllib package. The book is converted into a list and decoded using the UTF-8 format.

# %%
# import urllib to make HTTP requests for internet resources and random to generate random sets 
import urllib.request
import random

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book as a list
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# %% [markdown]
# Create a variable called chars that contains a string with all the letters of the alphabet in lower case and the space character.

# %%
chars = 'abcdefghijklmnopqrstuvwxyz '

# %% [markdown]
# Confirm chars is a string.

# %%
type(chars)
# Out:
# str

# %% [markdown]
# Create a variable sbook to hold the characters in book as a single string. Create a variable weights that holds the occurrences of each character in chars as a list.

# %%
# the slicing statement [26:] is used to ignore the 25 line Gutenberg.com preamble at the start of the text
sbook = ''.join(book[26:]).lower()

# Create the weights - count the occurences of each character in the whole book.
weights = [sbook.count(c) for c in chars]

# Show the weights.
weights
# Out:
# [9801,
#  1743,
#  3008,
#  5455,
#  15402,
#  2374,
#  2938,
#  7902,
#  8611,
#  232,
#  1291,
#  5194,
#  2459,
#  8032,
#  9471,
#  1971,
#  223,
#  6617,
#  7246,
#  12225,
#  3970,
#  962,
#  2958,
#  181,
#  2592,
#  80,
#  26950]

# %% [markdown]
# Create a nested dictionary containing the weights of each letter based on the preceding two letters.

# %%
# Create the weights.
threeLetterWeights ={b: {c: {d: sbook.count(b + c + d) for d in chars} for c in chars} for b in chars}

# Show the weights.
threeLetterWeights
# Out:
# {'a': {'a': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'b': {'a': 0,
#    'b': 54,
#    'c': 0,
#    'd': 0,
#    'e': 7,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 7,
#    'j': 0,
#    'k': 0,
#    'l': 48,
#    'm': 0,
#    'n': 0,
#    'o': 106,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 3,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 15,
#    'z': 0,
#    ' ': 1},
#   'c': {'a': 0,
#    'b': 0,
#    'c': 28,
#    'd': 0,
#    'e': 48,
#    'f': 0,
#    'g': 0,
#    'h': 24,
#    'i': 2,
#    'j': 0,
#    'k': 48,
#    'l': 11,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 0,
#    'q': 0,
#    'r': 5,
#    's': 0,
#    't': 31,
#    'u': 7,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 5,
#    'b': 1,
#    'c': 1,
#    'd': 37,
#    'e': 56,
#    'f': 8,
#    'g': 0,
#    'h': 1,
#    'i': 13,
#    'j': 1,
#    'k': 0,
#    'l': 6,
#    'm': 0,
#    'n': 10,
#    'o': 4,
#    'p': 1,
#    'q': 0,
#    'r': 7,
#    's': 13,
#    't': 1,
#    'u': 0,
#    'v': 20,
#    'w': 1,
#    'x': 0,
#    'y': 15,
#    'z': 0,
#    ' ': 235},
#   'e': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 4,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 13,
#    's': 0,
#    't': 45,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 93,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 59,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 1,
#    'q': 0,
#    'r': 48,
#    's': 1,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'h': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 9},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 483,
#    'e': 0,
#    'f': 0,
#    'g': 4,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 23,
#    'm': 12,
#    'n': 162,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 39,
#    's': 8,
#    't': 21,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 12,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 88,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 23,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 12},
#   'l': {'a': 11,
#    'b': 0,
#    'c': 2,
#    'd': 1,
#    'e': 13,
#    'f': 24,
#    'g': 0,
#    'h': 0,
#    'i': 410,
#    'j': 0,
#    'k': 53,
#    'l': 334,
#    'm': 9,
#    'n': 0,
#    'o': 17,
#    'p': 0,
#    'q': 0,
#    'r': 5,
#    's': 12,
#    't': 19,
#    'u': 0,
#    'v': 1,
#    'w': 14,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 71},
#   'm': {'a': 9,
#    'b': 2,
#    'c': 0,
#    'd': 0,
#    'e': 109,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 18,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 1,
#    'n': 1,
#    'o': 18,
#    'p': 5,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 1,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 23},
#   'n': {'a': 21,
#    'b': 1,
#    'c': 73,
#    'd': 1022,
#    'e': 2,
#    'f': 0,
#    'g': 58,
#    'h': 0,
#    'i': 25,
#    'j': 0,
#    'k': 9,
#    'l': 0,
#    'm': 0,
#    'n': 17,
#    'o': 23,
#    'p': 0,
#    'q': 1,
#    'r': 1,
#    's': 26,
#    't': 82,
#    'u': 2,
#    'v': 1,
#    'w': 1,
#    'x': 17,
#    'y': 119,
#    'z': 0,
#    ' ': 201},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 16,
#    'f': 0,
#    'g': 0,
#    'h': 16,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 58,
#    'q': 0,
#    'r': 2,
#    's': 19,
#    't': 24,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 5},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 16,
#    'b': 0,
#    'c': 62,
#    'd': 111,
#    'e': 151,
#    'f': 0,
#    'g': 56,
#    'h': 0,
#    'i': 25,
#    'j': 0,
#    'k': 63,
#    'l': 20,
#    'm': 29,
#    'n': 16,
#    'o': 6,
#    'p': 11,
#    'q': 1,
#    'r': 28,
#    's': 29,
#    't': 65,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 24,
#    'z': 0,
#    ' ': 73},
#   's': {'a': 8,
#    'b': 0,
#    'c': 3,
#    'd': 0,
#    'e': 45,
#    'f': 0,
#    'g': 3,
#    'h': 22,
#    'i': 12,
#    'j': 0,
#    'k': 34,
#    'l': 10,
#    'm': 1,
#    'n': 17,
#    'o': 15,
#    'p': 2,
#    'q': 1,
#    'r': 0,
#    's': 47,
#    't': 97,
#    'u': 4,
#    'v': 1,
#    'w': 2,
#    'x': 0,
#    'y': 4,
#    'z': 0,
#    ' ': 578},
#   't': {'a': 8,
#    'b': 0,
#    'c': 25,
#    'd': 2,
#    'e': 169,
#    'f': 1,
#    'g': 0,
#    'h': 50,
#    'i': 126,
#    'j': 0,
#    'k': 0,
#    'l': 6,
#    'm': 3,
#    'n': 0,
#    'o': 6,
#    'p': 0,
#    'q': 1,
#    'r': 2,
#    's': 23,
#    't': 97,
#    'u': 24,
#    'v': 0,
#    'w': 5,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 654},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 7,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 14,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 4,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 28,
#    't': 22,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 6,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 146,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 19,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 3,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 30,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 7,
#    'm': 0,
#    'n': 4,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 18,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 22},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 6},
#   'y': {'a': 0,
#    'b': 2,
#    'c': 2,
#    'd': 1,
#    'e': 6,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 24,
#    'j': 0,
#    'k': 1,
#    'l': 0,
#    'm': 3,
#    'n': 1,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 28,
#    't': 2,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 149},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 2,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 7,
#    'b': 34,
#    'c': 56,
#    'd': 32,
#    'e': 0,
#    'f': 34,
#    'g': 40,
#    'h': 18,
#    'i': 0,
#    'j': 3,
#    'k': 5,
#    'l': 116,
#    'm': 45,
#    'n': 18,
#    'o': 3,
#    'p': 40,
#    'q': 3,
#    'r': 33,
#    's': 55,
#    't': 45,
#    'u': 4,
#    'v': 27,
#    'w': 36,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0}},
#  'b': {'a': {'a': 0,
#    'b': 14,
#    'c': 40,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 1,
#    'l': 2,
#    'm': 0,
#    'n': 5,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 6,
#    's': 2,
#    't': 8,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'b': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 59,
#    'j': 0,
#    'k': 0,
#    'l': 7,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 34,
#    'b': 1,
#    'c': 24,
#    'd': 6,
#    'e': 40,
#    'f': 43,
#    'g': 108,
#    'h': 18,
#    'i': 20,
#    'j': 0,
#    'k': 1,
#    'l': 30,
#    'm': 1,
#    'n': 4,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 124,
#    's': 18,
#    't': 21,
#    'u': 1,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 144},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 24,
#    'm': 0,
#    'n': 6,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 13,
#    's': 2,
#    't': 75,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 8,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 5,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 83,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 20,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 5,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 10,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 3,
#    'b': 0,
#    'c': 0,
#    'd': 25,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 2,
#    'o': 32,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 30,
#    'u': 108,
#    'v': 3,
#    'w': 9,
#    'x': 11,
#    'y': 3,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 8,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 19,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 19,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 14,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 2,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 0,
#    'b': 0,
#    'c': 1,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 16,
#    'u': 2,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 5},
#   't': {'a': 5,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 4,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 7,
#    's': 14,
#    't': 218,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 1,
#    'b': 1,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 2,
#    'u': 1,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 83},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 1,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0}},
#  'c': {'a': {'a': 0,
#    'b': 3,
#    'c': 1,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 6,
#    'l': 36,
#    'm': 43,
#    'n': 84,
#    'o': 0,
#    'p': 9,
#    'q': 0,
#    'r': 28,
#    's': 7,
#    't': 101,
#    'u': 35,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'b': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 20,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 5,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 6,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 3,
#    'b': 1,
#    'c': 3,
#    'd': 18,
#    'e': 5,
#    'f': 1,
#    'g': 1,
#    'h': 2,
#    'i': 12,
#    'j': 0,
#    'k': 0,
#    'l': 6,
#    'm': 6,
#    'n': 19,
#    'o': 2,
#    'p': 17,
#    'q': 0,
#    'r': 30,
#    's': 39,
#    't': 2,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 339},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 76,
#    'b': 2,
#    'c': 1,
#    'd': 1,
#    'e': 93,
#    'f': 1,
#    'g': 0,
#    'h': 0,
#    'i': 67,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 2,
#    'n': 3,
#    'o': 32,
#    'p': 0,
#    'q': 0,
#    'r': 3,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 2,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 212},
#   'i': {'a': 17,
#    'b': 0,
#    'c': 0,
#    'd': 11,
#    'e': 4,
#    'f': 2,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 4,
#    'm': 0,
#    'n': 4,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 0,
#    't': 5,
#    'u': 0,
#    'v': 4,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 20,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 12,
#    'j': 0,
#    'k': 0,
#    'l': 6,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 6,
#    't': 5,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 108},
#   'l': {'a': 22,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 21,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 22,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 19,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 5,
#    'b': 0,
#    'c': 0,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 9,
#    'm': 107,
#    'n': 95,
#    'o': 15,
#    'p': 48,
#    'q': 0,
#    'r': 10,
#    's': 5,
#    't': 0,
#    'u': 152,
#    'v': 4,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 12,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 34,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 28,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 40,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 6,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   't': {'a': 4,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 13,
#    'f': 1,
#    'g': 16,
#    'h': 0,
#    'i': 36,
#    'j': 0,
#    'k': 0,
#    'l': 17,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 29,
#    's': 4,
#    't': 0,
#    'u': 10,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 88},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 2,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 18,
#    'm': 3,
#    'n': 1,
#    'o': 0,
#    'p': 10,
#    'q': 0,
#    'r': 42,
#    's': 11,
#    't': 26,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 4},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 2,
#    'b': 2,
#    'c': 0,
#    'd': 2,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 1,
#    'u': 0,
#    'v': 0,
#    'w': 27,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0}},
#  'd': {'a': {'a': 0,
#    'b': 3,
#    'c': 0,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 9,
#    'm': 7,
#    'n': 20,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 11,
#    's': 1,
#    't': 33,
#    'u': 1,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 43,
#    'z': 0,
#    ' ': 3},
#   'b': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 7,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 3,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 1,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 43,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 9,
#    'j': 0,
#    'k': 0,
#    'l': 12,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 6,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 2,
#    'z': 0,
#    ' ': 1},
#   'e': {'a': 66,
#    'b': 0,
#    'c': 10,
#    'd': 81,
#    'e': 28,
#    'f': 8,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 9,
#    'm': 18,
#    'n': 73,
#    'o': 1,
#    'p': 2,
#    'q': 0,
#    'r': 125,
#    's': 27,
#    't': 2,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 57},
#   'f': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 8,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 29,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 6,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 2,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 7,
#    'b': 1,
#    'c': 9,
#    'd': 78,
#    'e': 15,
#    'f': 19,
#    'g': 10,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 0,
#    'n': 69,
#    'o': 2,
#    'p': 2,
#    'q': 0,
#    'r': 16,
#    's': 70,
#    't': 19,
#    'u': 5,
#    'v': 5,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 16,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 47,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 7,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 1,
#    'b': 0,
#    'c': 1,
#    'd': 14,
#    'e': 27,
#    'f': 3,
#    'g': 6,
#    'h': 0,
#    'i': 7,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 3,
#    'n': 109,
#    'o': 33,
#    'p': 2,
#    'q': 0,
#    'r': 40,
#    's': 1,
#    't': 4,
#    'u': 12,
#    'v': 1,
#    'w': 116,
#    'x': 0,
#    'y': 0,
#    'z': 2,
#    ' ': 80},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 13,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 43,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 18,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 10,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 2,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 8,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 3,
#    'b': 0,
#    'c': 0,
#    'd': 1,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 5,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 3,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 3,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 53},
#   't': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 24,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 8,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'u': {'a': 4,
#    'b': 0,
#    'c': 59,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 1,
#    'n': 1,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 6,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 9,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 1,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 1,
#    'n': 1,
#    'o': 3,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 32},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 391,
#    'b': 136,
#    'c': 46,
#    'd': 63,
#    'e': 31,
#    'f': 75,
#    'g': 50,
#    'h': 161,
#    'i': 179,
#    'j': 11,
#    'k': 7,
#    'l': 55,
#    'm': 57,
#    'n': 110,
#    'o': 145,
#    'p': 43,
#    'q': 13,
#    'r': 49,
#    's': 194,
#    't': 770,
#    'u': 41,
#    'v': 24,
#    'w': 126,
#    'x': 0,
#    'y': 41,
#    'z': 0,
#    ' ': 0}},
#  'e': {'a': {'a': 0,
#    'b': 1,
#    'c': 31,
#    'd': 137,
#    'e': 0,
#    'f': 0,
#    'g': 18,
#    'h': 1,
#    'i': 0,
#    'j': 0,
#    'k': 29,
#    'l': 38,
#    'm': 18,
#    'n': 41,
#    'o': 1,
#    'p': 5,
#    'q': 0,
#    'r': 213,
#    's': 77,
#    't': 129,
#    'u': 21,
#    'v': 18,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 23},
#   'b': {'a': 2,
#    'b': 2,
#    'c': 0,
#    'd': 0,
#    'e': 11,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 5,
#    'j': 0,
#    'k': 0,
#    'l': 4,
#    'm': 0,
#    'n': 0,
#    'o': 22,
#    'p': 0,
#    'q': 0,
#    'r': 3,
#    's': 4,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 1},
#   'c': {'a': 23,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 23,
#    'f': 0,
#    'g': 0,
#    'h': 8,
#    'i': 12,
#    'j': 0,
#    'k': 14,
#    'l': 3,
#    'm': 0,
#    'n': 0,
#    'o': 32,
#    'p': 0,
#    'q': 0,
#    'r': 3,
#    's': 0,
#    't': 189,
#    'u': 22,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 6,
#    'b': 2,
#    'c': 0,
#    'd': 2,
#    'e': 6,
#    'f': 1,
#    'g': 21,
#    'h': 2,
#    'i': 36,
#    'j': 0,
#    'k': 0,
#    'l': 8,
#    'm': 1,
#    'n': 4,
#    'o': 10,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 10,
#    't': 12,
#    'u': 9,
#    'v': 0,
#    'w': 6,
#    'x': 0,
#    'y': 2,
#    'z': 0,
#    ' ': 770},
#   'e': {'a': 1,
#    'b': 3,
#    'c': 3,
#    'd': 32,
#    'e': 0,
#    'f': 1,
#    'g': 1,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 7,
#    'l': 29,
#    'm': 58,
#    'n': 146,
#    'o': 0,
#    'p': 56,
#    'q': 0,
#    'r': 24,
#    's': 13,
#    't': 26,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 2,
#    'y': 0,
#    'z': 14,
#    ' ': 101},
#   'f': {'a': 2,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 12,
#    'f': 8,
#    'g': 0,
#    'h': 0,
#    'i': 5,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 0,
#    'n': 0,
#    'o': 44,
#    'p': 0,
#    'q': 0,
#    'r': 5,
#    's': 0,
#    't': 16,
#    'u': 20,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 1},
#   'g': {'a': 64,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 3,
#    'f': 0,
#    'g': 9,
#    'h': 0,
#    'i': 35,
#    'j': 0,
#    'k': 0,
#    'l': 3,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 9,
#    's': 4,
#    't': 0,
#    'u': 10,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 7},
#   'h': {'a': 10,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 12,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 13,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 17,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 1,
#    'g': 7,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 1,
#    'n': 25,
#    'o': 0,
#    'p': 2,
#    'q': 0,
#    'r': 53,
#    's': 0,
#    't': 13,
#    'u': 0,
#    'v': 9,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 4,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 2,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 0,
#    'n': 1,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 3,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 5},
#   'l': {'a': 7,
#    'b': 4,
#    'c': 1,
#    'd': 6,
#    'e': 44,
#    'f': 122,
#    'g': 0,
#    'h': 0,
#    'i': 41,
#    'j': 0,
#    'k': 0,
#    'l': 124,
#    'm': 0,
#    'n': 0,
#    'o': 17,
#    'p': 15,
#    'q': 0,
#    'r': 0,
#    's': 16,
#    't': 26,
#    'u': 0,
#    'v': 11,
#    'w': 0,
#    'x': 0,
#    'y': 47,
#    'z': 0,
#    ' ': 15},
#   'm': {'a': 55,
#    'b': 31,
#    'c': 0,
#    'd': 0,
#    'e': 80,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 10,
#    'o': 11,
#    'p': 20,
#    'q': 0,
#    'r': 0,
#    's': 8,
#    't': 1,
#    'u': 5,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 57},
#   'n': {'a': 6,
#    'b': 95,
#    'c': 54,
#    'd': 59,
#    'e': 59,
#    'f': 1,
#    'g': 12,
#    'h': 1,
#    'i': 17,
#    'j': 1,
#    'k': 2,
#    'l': 13,
#    'm': 0,
#    'n': 3,
#    'o': 23,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 47,
#    't': 299,
#    'u': 3,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 327},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 7,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 15,
#    'o': 0,
#    'p': 16,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 4,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 11,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 28,
#    'f': 0,
#    'g': 0,
#    'h': 2,
#    'i': 8,
#    'j': 0,
#    'k': 0,
#    'l': 48,
#    'm': 0,
#    'n': 0,
#    'o': 3,
#    'p': 9,
#    'q': 0,
#    'r': 6,
#    's': 2,
#    't': 30,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 25},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 19,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 51,
#    'b': 2,
#    'c': 9,
#    'd': 9,
#    'e': 343,
#    'f': 17,
#    'g': 96,
#    'h': 23,
#    'i': 40,
#    'j': 0,
#    'k': 1,
#    'l': 15,
#    'm': 34,
#    'n': 12,
#    'o': 4,
#    'p': 45,
#    'q': 2,
#    'r': 20,
#    's': 215,
#    't': 34,
#    'u': 0,
#    'v': 8,
#    'w': 11,
#    'x': 0,
#    'y': 185,
#    'z': 0,
#    ' ': 673},
#   's': {'a': 8,
#    'b': 0,
#    'c': 10,
#    'd': 0,
#    'e': 44,
#    'f': 2,
#    'g': 1,
#    'h': 12,
#    'i': 7,
#    'j': 0,
#    'k': 3,
#    'l': 0,
#    'm': 0,
#    'n': 17,
#    'o': 7,
#    'p': 11,
#    'q': 1,
#    'r': 1,
#    's': 145,
#    't': 99,
#    'u': 4,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 208},
#   't': {'a': 7,
#    'b': 0,
#    'c': 13,
#    'd': 0,
#    'e': 10,
#    'f': 1,
#    'g': 0,
#    'h': 70,
#    'i': 14,
#    'j': 0,
#    'k': 0,
#    'l': 5,
#    'm': 0,
#    'n': 0,
#    'o': 9,
#    'p': 0,
#    'q': 0,
#    'r': 4,
#    's': 5,
#    't': 56,
#    'u': 9,
#    'v': 0,
#    'w': 7,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 120},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 4,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 2},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 195,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 10,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 9,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 5,
#    'f': 0,
#    'g': 0,
#    'h': 6,
#    'i': 8,
#    'j': 0,
#    'k': 1,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 4,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 2,
#    't': 4,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 36},
#   'x': {'a': 12,
#    'b': 0,
#    'c': 18,
#    'd': 0,
#    'e': 21,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 2,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 30,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 40,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 2,
#    'b': 0,
#    'c': 2,
#    'd': 0,
#    'e': 38,
#    'f': 0,
#    'g': 0,
#    'h': 2,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 6,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 1,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 134},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 8,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 306,
#    'b': 149,
#    'c': 281,
#    'd': 251,
#    'e': 71,
#    'f': 214,
#    'g': 169,
#    'h': 265,
#    'i': 193,
#    'j': 39,
#    'k': 103,
#    'l': 147,
#    'm': 241,
#    'n': 92,
#    'o': 320,
#    'p': 173,
#    'q': 87,
#    'r': 166,
#    's': 394,
#    't': 542,
#    'u': 52,
#    'v': 29,
#    'w': 451,
#    'x': 0,
#    'y': 62,
#    'z': 0,
#    ' ': 0}},
#  'f': {'a': {'a': 0,
#    'b': 0,
#    'c': 29,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 8,
#    'j': 0,
#    'k': 0,
#    'l': 14,
#    'm': 2,
#    'n': 24,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 16,
#    's': 9,
#    't': 8,
#    'u': 1,
#    'v': 2,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 2},
#   'b': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 3,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 7,
#    'b': 1,
#    'c': 15,
#    'd': 3,
#    'e': 52,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 35,
#    'm': 0,
#    'n': 12,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 17,
#    's': 1,
#    't': 7,
#    'u': 0,
#    'v': 0,
#    'w': 10,
#    'x': 1,
#    'y': 0,
#    'z': 0,
#    ' ': 4},
#   'f': {'a': 3,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 30,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 16,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 6,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 48},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 20,
#    'd': 2,
#    'e': 6,
#    'f': 3,
#    'g': 8,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 8,
#    'm': 0,
#    'n': 53,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 58,
#    's': 11,
#    't': 10,
#    'u': 0,
#    'v': 8,
#    'w': 0,
#    'x': 3,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 14,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 3,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 9,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 4,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 5,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 24,
#    'm': 0,
#    'n': 5,
#    'o': 28,
#    'p': 0,
#    'q': 0,
#    'r': 294,
#    's': 0,
#    't': 0,
#    'u': 72,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 15,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 19,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 16,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 63,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 1,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   't': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 54,
#    'f': 0,
#    'g': 0,
#    'h': 15,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 0,
#    'o': 1,
#    'p': 0,
#    'q': 0,
#    'r': 1,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 13},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 78,
#    'm': 1,
#    'n': 16,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 14,
#    's': 13,
#    't': 3,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
# ...
#   'c': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 1,
#    'b': 0,
#    'c': 0,
#    'd': 4,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 8,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 10},
#   'f': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 1,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 1,
#    'm': 0,
#    'n': 8,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'j': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 10,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'p': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   't': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 1,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 14,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0}},
#  ' ': {'a': {'a': 0,
#    'b': 100,
#    'c': 39,
#    'd': 54,
#    'e': 0,
#    'f': 57,
#    'g': 120,
#    'h': 5,
#    'i': 15,
#    'j': 0,
#    'k': 0,
#    'l': 567,
#    'm': 34,
#    'n': 1009,
#    'o': 0,
#    'p': 20,
#    'q': 0,
#    'r': 110,
#    's': 307,
#    't': 223,
#    'u': 3,
#    'v': 5,
#    'w': 30,
#    'x': 2,
#    'y': 0,
#    'z': 0,
#    ' ': 600},
#   'b': {'a': 76,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 449,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 42,
#    'j': 0,
#    'k': 0,
#    'l': 11,
#    'm': 0,
#    'n': 0,
#    'o': 64,
#    'p': 0,
#    'q': 0,
#    'r': 53,
#    's': 0,
#    't': 0,
#    'u': 138,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 76,
#    'z': 0,
#    ' ': 0},
#   'c': {'a': 274,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 20,
#    'f': 0,
#    'g': 0,
#    'h': 106,
#    'i': 6,
#    'j': 0,
#    'k': 0,
#    'l': 35,
#    'm': 0,
#    'n': 0,
#    'o': 338,
#    'p': 0,
#    'q': 0,
#    'r': 91,
#    's': 0,
#    't': 0,
#    'u': 48,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'd': {'a': 68,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 101,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 179,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 393,
#    'p': 0,
#    'q': 0,
#    'r': 55,
#    's': 0,
#    't': 0,
#    'u': 46,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'e': {'a': 63,
#    'b': 13,
#    'c': 0,
#    'd': 13,
#    'e': 2,
#    'f': 7,
#    'g': 6,
#    'h': 0,
#    'i': 8,
#    'j': 0,
#    'k': 0,
#    'l': 41,
#    'm': 6,
#    'n': 61,
#    'o': 0,
#    'p': 0,
#    'q': 3,
#    'r': 1,
#    's': 6,
#    't': 0,
#    'u': 0,
#    'v': 71,
#    'w': 0,
#    'x': 73,
#    'y': 35,
#    'z': 0,
#    ' ': 0},
#   'f': {'a': 99,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 102,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 136,
#    'j': 0,
#    'k': 0,
#    'l': 27,
#    'm': 0,
#    'n': 0,
#    'o': 303,
#    'p': 0,
#    'q': 0,
#    'r': 78,
#    's': 0,
#    't': 0,
#    'u': 39,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'g': {'a': 54,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 78,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 23,
#    'j': 0,
#    'k': 0,
#    'l': 30,
#    'm': 0,
#    'n': 0,
#    'o': 167,
#    'p': 0,
#    'q': 0,
#    'r': 163,
#    's': 0,
#    't': 0,
#    'u': 86,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'h': {'a': 497,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 602,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 163,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 136,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 39,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   'i': {'a': 0,
#    'b': 0,
#    'c': 1,
#    'd': 18,
#    'e': 0,
#    'f': 90,
#    'g': 1,
#    'h': 1,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 2,
#    'm': 26,
#    'n': 570,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 2,
#    's': 121,
#    't': 587,
#    'u': 1,
#    'v': 2,
#    'w': 3,
#    'x': 2,
#    'y': 0,
#    'z': 0,
#    ' ': 227},
#   'j': {'a': 6,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 15,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 85,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'k': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 34,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 86,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 125,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'l': {'a': 124,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 96,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 302,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 207,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 8,
#    'z': 0,
#    ' ': 0},
#   'm': {'a': 239,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 132,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 111,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 234,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 121,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 59,
#    'z': 0,
#    ' ': 0},
#   'n': {'a': 20,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 134,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 21,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 348,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 10,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'o': {'a': 0,
#    'b': 10,
#    'c': 3,
#    'd': 1,
#    'e': 0,
#    'f': 677,
#    'g': 0,
#    'h': 14,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 23,
#    'm': 0,
#    'n': 358,
#    'o': 0,
#    'p': 30,
#    'q': 0,
#    'r': 149,
#    's': 0,
#    't': 57,
#    'u': 145,
#    'v': 40,
#    'w': 20,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 1},
#   'p': {'a': 124,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 75,
#    'f': 0,
#    'g': 2,
#    'h': 5,
#    'i': 50,
#    'j': 0,
#    'k': 0,
#    'l': 65,
#    'm': 0,
#    'n': 0,
#    'o': 71,
#    'p': 0,
#    'q': 0,
#    'r': 162,
#    's': 0,
#    't': 0,
#    'u': 68,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'q': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 171,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'r': {'a': 116,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 246,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 49,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 82,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 29,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   's': {'a': 586,
#    'b': 0,
#    'c': 18,
#    'd': 0,
#    'e': 216,
#    'f': 0,
#    'g': 0,
#    'h': 661,
#    'i': 131,
#    'j': 0,
#    'k': 7,
#    'l': 35,
#    'm': 24,
#    'n': 17,
#    'o': 325,
#    'p': 57,
#    'q': 5,
#    'r': 0,
#    's': 0,
#    't': 129,
#    'u': 136,
#    'v': 0,
#    'w': 15,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   't': {'a': 110,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 106,
#    'f': 0,
#    'g': 0,
#    'h': 2778,
#    'i': 117,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 892,
#    'p': 0,
#    'q': 0,
#    'r': 117,
#    's': 0,
#    't': 0,
#    'u': 101,
#    'v': 0,
#    'w': 57,
#    'x': 0,
#    'y': 1,
#    'z': 0,
#    ' ': 0},
#   'u': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 5,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 77,
#    'o': 0,
#    'p': 127,
#    'q': 0,
#    'r': 0,
#    's': 77,
#    't': 1,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'v': {'a': 11,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 137,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 18,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 56,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 1,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'w': {'a': 492,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 243,
#    'f': 0,
#    'g': 0,
#    'h': 384,
#    'i': 337,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 273,
#    'p': 0,
#    'q': 0,
#    'r': 32,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 5,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'x': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 4,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'y': {'a': 4,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 31,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 470,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   'z': {'a': 0,
#    'b': 0,
#    'c': 0,
#    'd': 0,
#    'e': 1,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 1,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 0,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 0,
#    'u': 0,
#    'v': 0,
#    'w': 0,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 0},
#   ' ': {'a': 4,
#    'b': 0,
#    'c': 0,
#    'd': 1,
#    'e': 0,
#    'f': 0,
#    'g': 0,
#    'h': 0,
#    'i': 0,
#    'j': 0,
#    'k': 0,
#    'l': 0,
#    'm': 0,
#    'n': 0,
#    'o': 0,
#    'p': 1,
#    'q': 0,
#    'r': 0,
#    's': 0,
#    't': 5,
#    'u': 0,
#    'v': 0,
#    'w': 1,
#    'x': 0,
#    'y': 0,
#    'z': 0,
#    ' ': 113}}}

# %% [markdown]
# Create a dict threeletterdict to hold the occurrences of each three letter permutation. The for loop creates the new dict where the keys are all possible permutations of the nested keys in threeLetterWeights. The values are their occurrences.

# %%
#identify the most common three letter combination
threeletterdict = {}
for i in chars:
    for j in chars:
        for k in chars:
            name = threeLetterWeights[i][j][k]
            #print(i,j,k,' ',name)
            threeletterdict[i + j + k] = name

# %%
threeletterdict
# Out:
# {'aaa': 0,
#  'aab': 0,
#  'aac': 0,
#  'aad': 0,
#  'aae': 0,
#  'aaf': 0,
#  'aag': 0,
#  'aah': 0,
#  'aai': 0,
#  'aaj': 0,
#  'aak': 0,
#  'aal': 0,
#  'aam': 0,
#  'aan': 0,
#  'aao': 0,
#  'aap': 0,
#  'aaq': 0,
#  'aar': 0,
#  'aas': 0,
#  'aat': 0,
#  'aau': 0,
#  'aav': 0,
#  'aaw': 0,
#  'aax': 0,
#  'aay': 0,
#  'aaz': 0,
#  'aa ': 0,
#  'aba': 0,
#  'abb': 54,
#  'abc': 0,
#  'abd': 0,
#  'abe': 7,
#  'abf': 0,
#  'abg': 0,
#  'abh': 0,
#  'abi': 7,
#  'abj': 0,
#  'abk': 0,
#  'abl': 48,
#  'abm': 0,
#  'abn': 0,
#  'abo': 106,
#  'abp': 0,
#  'abq': 0,
#  'abr': 0,
#  'abs': 3,
#  'abt': 0,
#  'abu': 0,
#  'abv': 0,
#  'abw': 0,
#  'abx': 0,
#  'aby': 15,
#  'abz': 0,
#  'ab ': 1,
#  'aca': 0,
#  'acb': 0,
#  'acc': 28,
#  'acd': 0,
#  'ace': 48,
#  'acf': 0,
#  'acg': 0,
#  'ach': 24,
#  'aci': 2,
#  'acj': 0,
#  'ack': 48,
#  'acl': 11,
#  'acm': 0,
#  'acn': 0,
#  'aco': 4,
#  'acp': 0,
#  'acq': 0,
#  'acr': 5,
#  'acs': 0,
#  'act': 31,
#  'acu': 7,
#  'acv': 0,
#  'acw': 0,
#  'acx': 0,
#  'acy': 0,
#  'acz': 0,
#  'ac ': 0,
#  'ada': 5,
#  'adb': 1,
#  'adc': 1,
#  'add': 37,
#  'ade': 56,
#  'adf': 8,
#  'adg': 0,
#  'adh': 1,
#  'adi': 13,
#  'adj': 1,
#  'adk': 0,
#  'adl': 6,
#  'adm': 0,
#  'adn': 10,
#  'ado': 4,
#  'adp': 1,
#  'adq': 0,
#  'adr': 7,
#  'ads': 13,
#  'adt': 1,
#  'adu': 0,
#  'adv': 20,
#  'adw': 1,
#  'adx': 0,
#  'ady': 15,
#  'adz': 0,
#  'ad ': 235,
#  'aea': 0,
#  'aeb': 0,
#  'aec': 0,
#  'aed': 0,
#  'aee': 0,
#  'aef': 0,
#  'aeg': 0,
#  'aeh': 0,
#  'aei': 0,
#  'aej': 0,
#  'aek': 0,
#  'ael': 1,
#  'aem': 0,
#  'aen': 0,
#  'aeo': 0,
#  'aep': 0,
#  'aeq': 0,
#  'aer': 0,
#  'aes': 0,
#  'aet': 0,
#  'aeu': 0,
#  'aev': 0,
#  'aew': 0,
#  'aex': 0,
#  'aey': 0,
#  'aez': 0,
#  'ae ': 0,
#  'afa': 0,
#  'afb': 0,
#  'afc': 0,
#  'afd': 0,
#  'afe': 2,
#  'aff': 4,
#  'afg': 0,
#  'afh': 0,
#  'afi': 1,
#  'afj': 0,
#  'afk': 0,
#  'afl': 0,
#  'afm': 0,
#  'afn': 0,
#  'afo': 1,
#  'afp': 0,
#  'afq': 0,
#  'afr': 13,
#  'afs': 0,
#  'aft': 45,
#  'afu': 1,
#  'afv': 0,
#  'afw': 0,
#  'afx': 0,
#  'afy': 0,
#  'afz': 0,
#  'af ': 0,
#  'aga': 93,
#  'agb': 0,
#  'agc': 0,
#  'agd': 0,
#  'age': 59,
#  'agf': 0,
#  'agg': 1,
#  'agh': 0,
#  'agi': 6,
#  'agj': 0,
#  'agk': 0,
#  'agl': 3,
#  'agm': 0,
#  'agn': 0,
#  'ago': 4,
#  'agp': 1,
#  'agq': 0,
#  'agr': 48,
#  'ags': 1,
#  'agt': 0,
#  'agu': 1,
#  'agv': 0,
#  'agw': 0,
#  'agx': 0,
#  'agy': 0,
#  'agz': 0,
#  'ag ': 1,
#  'aha': 0,
#  'ahb': 0,
#  'ahc': 0,
#  'ahd': 0,
#  'ahe': 2,
#  'ahf': 0,
#  'ahg': 0,
#  'ahh': 0,
#  'ahi': 1,
#  'ahj': 0,
#  'ahk': 0,
#  'ahl': 0,
#  'ahm': 0,
#  'ahn': 0,
#  'aho': 2,
#  'ahp': 0,
#  'ahq': 0,
#  'ahr': 0,
#  'ahs': 0,
#  'aht': 0,
#  'ahu': 1,
#  'ahv': 0,
#  'ahw': 0,
#  'ahx': 0,
#  'ahy': 0,
#  'ahz': 0,
#  'ah ': 9,
#  'aia': 0,
#  'aib': 0,
#  'aic': 0,
#  'aid': 483,
#  'aie': 0,
#  'aif': 0,
#  'aig': 4,
#  'aih': 0,
#  'aii': 0,
#  'aij': 0,
#  'aik': 0,
#  'ail': 23,
#  'aim': 12,
#  'ain': 162,
#  'aio': 0,
#  'aip': 0,
#  'aiq': 0,
#  'air': 39,
#  'ais': 8,
#  'ait': 21,
#  'aiu': 0,
#  'aiv': 0,
#  'aiw': 0,
#  'aix': 0,
#  'aiy': 0,
#  'aiz': 0,
#  'ai ': 0,
#  'aja': 0,
#  'ajb': 0,
#  'ajc': 0,
#  'ajd': 0,
#  'aje': 12,
#  'ajf': 0,
#  'ajg': 0,
#  'ajh': 0,
#  'aji': 0,
#  'ajj': 0,
#  'ajk': 0,
#  'ajl': 0,
#  'ajm': 0,
#  'ajn': 0,
#  'ajo': 0,
#  'ajp': 0,
#  'ajq': 0,
#  'ajr': 0,
#  'ajs': 0,
#  'ajt': 0,
#  'aju': 0,
#  'ajv': 0,
#  'ajw': 0,
#  'ajx': 0,
#  'ajy': 0,
#  'ajz': 0,
#  'aj ': 0,
#  'aka': 0,
#  'akb': 0,
#  'akc': 0,
#  'akd': 0,
#  'ake': 88,
#  'akf': 1,
#  'akg': 0,
#  'akh': 0,
#  'aki': 23,
#  'akj': 0,
#  'akk': 0,
#  'akl': 0,
#  'akm': 0,
#  'akn': 0,
#  'ako': 0,
#  'akp': 0,
#  'akq': 0,
#  'akr': 0,
#  'aks': 0,
#  'akt': 0,
#  'aku': 0,
#  'akv': 0,
#  'akw': 0,
#  'akx': 0,
#  'aky': 0,
#  'akz': 0,
#  'ak ': 12,
#  'ala': 11,
#  'alb': 0,
#  'alc': 2,
#  'ald': 1,
#  'ale': 13,
#  'alf': 24,
#  'alg': 0,
#  'alh': 0,
#  'ali': 410,
#  'alj': 0,
#  'alk': 53,
#  'all': 334,
#  'alm': 9,
#  'aln': 0,
#  'alo': 17,
#  'alp': 0,
#  'alq': 0,
#  'alr': 5,
#  'als': 12,
#  'alt': 19,
#  'alu': 0,
#  'alv': 1,
#  'alw': 14,
#  'alx': 0,
#  'aly': 1,
#  'alz': 0,
#  'al ': 71,
#  'ama': 9,
#  'amb': 2,
#  'amc': 0,
#  'amd': 0,
#  'ame': 109,
#  'amf': 0,
#  'amg': 0,
#  'amh': 0,
#  'ami': 18,
#  'amj': 0,
#  'amk': 0,
#  'aml': 0,
#  'amm': 1,
#  'amn': 1,
#  'amo': 18,
#  'amp': 5,
#  'amq': 0,
#  'amr': 0,
#  'ams': 0,
#  'amt': 1,
#  'amu': 1,
#  'amv': 0,
#  'amw': 0,
#  'amx': 0,
#  'amy': 1,
#  'amz': 0,
#  'am ': 23,
#  'ana': 21,
#  'anb': 1,
#  'anc': 73,
#  'and': 1022,
#  'ane': 2,
#  'anf': 0,
#  'ang': 58,
#  'anh': 0,
#  'ani': 25,
#  'anj': 0,
#  'ank': 9,
#  'anl': 0,
#  'anm': 0,
#  'ann': 17,
#  'ano': 23,
#  'anp': 0,
#  'anq': 1,
#  'anr': 1,
#  'ans': 26,
#  'ant': 82,
#  'anu': 2,
#  'anv': 1,
#  'anw': 1,
#  'anx': 17,
#  'any': 119,
#  'anz': 0,
#  'an ': 201,
#  'aoa': 0,
#  'aob': 0,
#  'aoc': 0,
#  'aod': 0,
#  'aoe': 0,
#  'aof': 0,
#  'aog': 1,
#  'aoh': 0,
#  'aoi': 0,
#  'aoj': 0,
#  'aok': 0,
#  'aol': 0,
#  'aom': 0,
#  'aon': 0,
#  'aoo': 0,
#  'aop': 0,
#  'aoq': 0,
#  'aor': 2,
#  'aos': 0,
#  'aot': 0,
#  'aou': 0,
#  'aov': 0,
#  'aow': 0,
#  'aox': 0,
#  'aoy': 0,
#  'aoz': 0,
#  'ao ': 0,
#  'apa': 0,
#  'apb': 0,
#  'apc': 0,
#  'apd': 0,
#  'ape': 16,
#  'apf': 0,
#  'apg': 0,
#  'aph': 16,
#  'api': 6,
#  'apj': 0,
#  'apk': 0,
#  'apl': 0,
#  'apm': 0,
#  'apn': 0,
#  'apo': 1,
#  'app': 58,
#  'apq': 0,
#  'apr': 2,
#  'aps': 19,
#  'apt': 24,
#  'apu': 0,
#  'apv': 0,
#  'apw': 0,
#  'apx': 0,
#  'apy': 0,
#  'apz': 0,
#  'ap ': 5,
#  'aqa': 0,
#  'aqb': 0,
#  'aqc': 0,
#  'aqd': 0,
#  'aqe': 0,
#  'aqf': 0,
#  'aqg': 0,
#  'aqh': 0,
#  'aqi': 0,
#  'aqj': 0,
#  'aqk': 0,
#  'aql': 0,
#  'aqm': 0,
#  'aqn': 0,
#  'aqo': 0,
#  'aqp': 0,
#  'aqq': 0,
#  'aqr': 0,
#  'aqs': 0,
#  'aqt': 0,
#  'aqu': 0,
#  'aqv': 0,
#  'aqw': 0,
#  'aqx': 0,
#  'aqy': 0,
#  'aqz': 0,
#  'aq ': 0,
#  'ara': 16,
#  'arb': 0,
#  'arc': 62,
#  'ard': 111,
#  'are': 151,
#  'arf': 0,
#  'arg': 56,
#  'arh': 0,
#  'ari': 25,
#  'arj': 0,
#  'ark': 63,
#  'arl': 20,
#  'arm': 29,
#  'arn': 16,
#  'aro': 6,
#  'arp': 11,
#  'arq': 1,
#  'arr': 28,
#  'ars': 29,
#  'art': 65,
#  'aru': 1,
#  'arv': 0,
#  'arw': 0,
#  'arx': 0,
#  'ary': 24,
#  'arz': 0,
#  'ar ': 73,
#  'asa': 8,
#  'asb': 0,
#  'asc': 3,
#  'asd': 0,
#  'ase': 45,
#  'asf': 0,
#  'asg': 3,
#  'ash': 22,
#  'asi': 12,
#  'asj': 0,
#  'ask': 34,
#  'asl': 10,
#  'asm': 1,
#  'asn': 17,
#  'aso': 15,
#  'asp': 2,
#  'asq': 1,
#  'asr': 0,
#  'ass': 47,
#  'ast': 97,
#  'asu': 4,
#  'asv': 1,
#  'asw': 2,
#  'asx': 0,
#  'asy': 4,
#  'asz': 0,
#  'as ': 578,
#  'ata': 8,
#  'atb': 0,
#  'atc': 25,
#  'atd': 2,
#  'ate': 169,
#  'atf': 1,
#  'atg': 0,
#  'ath': 50,
#  'ati': 126,
#  'atj': 0,
#  'atk': 0,
#  'atl': 6,
#  'atm': 3,
#  'atn': 0,
#  'ato': 6,
#  'atp': 0,
#  'atq': 1,
#  'atr': 2,
#  'ats': 23,
#  'att': 97,
#  'atu': 24,
#  'atv': 0,
#  'atw': 5,
#  'atx': 0,
#  'aty': 1,
#  'atz': 0,
#  'at ': 654,
#  'aua': 0,
#  'aub': 0,
#  'auc': 7,
#  'aud': 1,
#  'aue': 0,
#  'auf': 0,
#  'aug': 14,
#  'auh': 0,
#  'aui': 0,
#  'auj': 0,
#  'auk': 0,
#  'aul': 4,
#  'aum': 0,
#  'aun': 0,
#  'auo': 0,
#  'aup': 0,
#  'auq': 0,
#  'aur': 0,
#  'aus': 28,
#  'aut': 22,
#  'auu': 0,
#  'auv': 0,
#  'auw': 0,
#  'aux': 0,
#  'auy': 0,
#  'auz': 0,
#  'au ': 0,
#  'ava': 6,
#  'avb': 0,
#  'avc': 0,
#  'avd': 0,
#  'ave': 146,
#  'avf': 0,
#  'avg': 0,
#  'avh': 0,
#  'avi': 19,
#  'avj': 0,
#  'avk': 0,
#  'avl': 0,
#  'avm': 0,
#  'avn': 0,
#  'avo': 4,
#  'avp': 0,
#  'avq': 0,
#  'avr': 0,
#  'avs': 0,
#  'avt': 0,
#  'avu': 0,
#  'avv': 0,
#  'avw': 0,
#  'avx': 0,
#  'avy': 3,
#  'avz': 0,
#  'av ': 0,
#  'awa': 30,
#  'awb': 0,
#  'awc': 0,
#  'awd': 0,
#  'awe': 0,
#  'awf': 1,
#  'awg': 0,
#  'awh': 0,
#  'awi': 1,
#  'awj': 0,
#  'awk': 0,
#  'awl': 7,
#  'awm': 0,
#  'awn': 4,
#  'awo': 0,
#  'awp': 0,
#  'awq': 0,
#  'awr': 1,
#  'aws': 18,
#  'awt': 0,
#  'awu': 0,
#  'awv': 0,
#  'aww': 0,
#  'awx': 0,
#  'awy': 0,
#  'awz': 0,
#  'aw ': 22,
#  'axa': 0,
#  'axb': 0,
#  'axc': 0,
#  'axd': 0,
#  'axe': 2,
#  'axf': 0,
#  'axg': 0,
#  'axh': 0,
#  'axi': 4,
#  'axj': 0,
#  'axk': 0,
#  'axl': 0,
#  'axm': 0,
#  'axn': 0,
#  'axo': 0,
#  'axp': 0,
#  'axq': 0,
#  'axr': 0,
#  'axs': 0,
#  'axt': 0,
#  'axu': 0,
#  'axv': 0,
#  'axw': 0,
#  'axx': 0,
#  'axy': 0,
#  'axz': 0,
#  'ax ': 6,
#  'aya': 0,
#  'ayb': 2,
#  'ayc': 2,
#  'ayd': 1,
#  'aye': 6,
#  'ayf': 1,
#  'ayg': 0,
#  'ayh': 0,
#  'ayi': 24,
#  'ayj': 0,
#  'ayk': 1,
#  'ayl': 0,
#  'aym': 3,
#  'ayn': 1,
#  'ayo': 1,
#  'ayp': 0,
#  'ayq': 0,
#  'ayr': 0,
#  'ays': 28,
#  'ayt': 2,
#  'ayu': 0,
#  'ayv': 0,
#  'ayw': 1,
#  'ayx': 0,
#  'ayy': 0,
#  'ayz': 0,
#  'ay ': 149,
#  'aza': 0,
#  'azb': 0,
#  'azc': 0,
#  'azd': 0,
#  'aze': 1,
#  'azf': 0,
#  'azg': 0,
#  'azh': 0,
#  'azi': 2,
#  'azj': 0,
#  'azk': 0,
#  'azl': 0,
#  'azm': 0,
#  'azn': 0,
#  'azo': 0,
#  'azp': 0,
#  'azq': 0,
#  'azr': 0,
#  'azs': 0,
#  'azt': 0,
#  'azu': 0,
#  'azv': 0,
#  'azw': 0,
#  'azx': 0,
#  'azy': 2,
#  'azz': 0,
#  'az ': 0,
#  'a a': 7,
#  'a b': 34,
#  'a c': 56,
#  'a d': 32,
#  'a e': 0,
#  'a f': 34,
#  'a g': 40,
#  'a h': 18,
#  'a i': 0,
#  'a j': 3,
#  'a k': 5,
#  'a l': 116,
#  'a m': 45,
#  'a n': 18,
#  'a o': 3,
#  'a p': 40,
#  'a q': 3,
#  'a r': 33,
#  'a s': 55,
#  'a t': 45,
#  'a u': 4,
#  'a v': 27,
#  'a w': 36,
#  'a x': 0,
#  'a y': 1,
#  'a z': 0,
#  'a  ': 0,
#  'baa': 0,
#  'bab': 14,
#  'bac': 40,
#  'bad': 2,
#  'bae': 0,
#  'baf': 0,
#  'bag': 1,
#  'bah': 0,
#  'bai': 0,
#  'baj': 0,
#  'bak': 1,
#  'bal': 2,
#  'bam': 0,
#  'ban': 5,
#  'bao': 0,
#  'bap': 0,
#  'baq': 0,
#  'bar': 6,
#  'bas': 2,
#  'bat': 8,
#  'bau': 0,
#  'bav': 0,
#  'baw': 1,
#  'bax': 0,
#  'bay': 0,
#  'baz': 0,
#  'ba ': 0,
#  'bba': 0,
#  'bbb': 0,
#  'bbc': 0,
#  'bbd': 0,
#  'bbe': 2,
#  'bbf': 0,
#  'bbg': 0,
#  'bbh': 0,
#  'bbi': 59,
#  'bbj': 0,
#  'bbk': 0,
#  'bbl': 7,
#  'bbm': 0,
#  'bbn': 0,
#  'bbo': 0,
#  'bbp': 0,
#  'bbq': 0,
#  'bbr': 0,
#  'bbs': 0,
#  'bbt': 0,
#  'bbu': 0,
#  'bbv': 0,
#  'bbw': 0,
#  'bbx': 0,
#  'bby': 0,
#  'bbz': 0,
#  'bb ': 0,
#  'bca': 0,
#  'bcb': 0,
#  'bcc': 0,
#  'bcd': 0,
#  'bce': 0,
#  'bcf': 0,
#  'bcg': 0,
#  'bch': 0,
#  'bci': 0,
#  'bcj': 0,
#  'bck': 0,
#  'bcl': 0,
#  'bcm': 0,
#  'bcn': 0,
#  'bco': 0,
#  'bcp': 0,
#  'bcq': 0,
#  'bcr': 0,
#  'bcs': 0,
#  'bct': 0,
#  'bcu': 0,
#  'bcv': 0,
#  'bcw': 0,
#  'bcx': 0,
#  'bcy': 0,
#  'bcz': 0,
#  'bc ': 0,
#  'bda': 0,
#  'bdb': 0,
#  'bdc': 0,
#  'bdd': 0,
#  'bde': 0,
#  'bdf': 0,
#  'bdg': 0,
#  'bdh': 0,
#  'bdi': 0,
#  'bdj': 0,
#  'bdk': 0,
#  'bdl': 0,
#  'bdm': 0,
#  'bdn': 0,
#  'bdo': 0,
#  'bdp': 0,
#  'bdq': 0,
#  'bdr': 0,
#  'bds': 0,
#  'bdt': 0,
#  'bdu': 1,
#  'bdv': 0,
#  'bdw': 0,
#  'bdx': 0,
#  'bdy': 0,
#  'bdz': 0,
#  'bd ': 0,
#  'bea': 34,
#  'beb': 1,
#  'bec': 24,
#  'bed': 6,
#  'bee': 40,
#  'bef': 43,
#  'beg': 108,
#  'beh': 18,
#  'bei': 20,
#  'bej': 0,
#  'bek': 1,
#  'bel': 30,
#  'bem': 1,
#  'ben': 4,
#  'beo': 1,
#  'bep': 0,
#  'beq': 0,
#  'ber': 124,
#  'bes': 18,
#  'bet': 21,
#  'beu': 1,
#  'bev': 0,
#  'bew': 1,
#  'bex': 0,
#  'bey': 1,
#  'bez': 0,
#  'be ': 144,
#  'bfa': 0,
#  'bfb': 0,
#  'bfc': 0,
#  'bfd': 0,
#  'bfe': 0,
#  'bff': 0,
#  'bfg': 0,
#  'bfh': 0,
#  'bfi': 0,
#  'bfj': 0,
#  'bfk': 0,
#  'bfl': 0,
#  'bfm': 0,
#  'bfn': 0,
#  'bfo': 0,
#  'bfp': 0,
#  'bfq': 0,
#  'bfr': 0,
#  'bfs': 0,
#  'bft': 0,
#  'bfu': 0,
#  'bfv': 0,
#  'bfw': 0,
#  'bfx': 0,
#  'bfy': 0,
#  'bfz': 0,
#  'bf ': 0,
#  'bga': 0,
#  'bgb': 0,
#  'bgc': 0,
#  'bgd': 0,
#  'bge': 0,
#  'bgf': 0,
#  'bgg': 0,
#  'bgh': 0,
#  'bgi': 0,
#  'bgj': 0,
#  'bgk': 0,
#  'bgl': 0,
#  'bgm': 0,
#  'bgn': 0,
#  'bgo': 0,
#  'bgp': 0,
#  'bgq': 0,
#  'bgr': 0,
#  'bgs': 0,
#  'bgt': 0,
#  'bgu': 0,
#  'bgv': 0,
#  'bgw': 0,
#  'bgx': 0,
#  'bgy': 0,
#  'bgz': 0,
#  'bg ': 0,
#  'bha': 0,
#  'bhb': 0,
#  'bhc': 0,
#  'bhd': 0,
#  'bhe': 0,
#  'bhf': 0,
#  'bhg': 0,
#  'bhh': 0,
#  'bhi': 0,
#  'bhj': 0,
#  'bhk': 0,
#  'bhl': 0,
#  'bhm': 0,
#  'bhn': 0,
#  'bho': 0,
#  'bhp': 0,
#  'bhq': 0,
#  'bhr': 0,
#  'bhs': 0,
#  'bht': 0,
#  'bhu': 0,
#  'bhv': 0,
#  'bhw': 0,
#  'bhx': 0,
#  'bhy': 0,
#  'bhz': 0,
#  'bh ': 0,
#  'bia': 0,
#  'bib': 0,
#  'bic': 0,
#  'bid': 2,
#  'bie': 0,
#  'bif': 0,
#  'big': 0,
#  'bih': 0,
#  'bii': 0,
#  'bij': 0,
#  'bik': 0,
#  'bil': 24,
#  'bim': 0,
#  'bin': 6,
#  'bio': 0,
#  'bip': 0,
#  'biq': 0,
#  'bir': 13,
#  'bis': 2,
#  'bit': 75,
#  'biu': 0,
#  'biv': 0,
#  'biw': 0,
#  'bix': 0,
#  'biy': 0,
#  'biz': 0,
#  'bi ': 0,
#  'bja': 0,
#  'bjb': 0,
#  'bjc': 0,
#  'bjd': 0,
#  'bje': 8,
#  'bjf': 0,
#  'bjg': 0,
#  'bjh': 0,
#  'bji': 0,
#  'bjj': 0,
#  'bjk': 0,
#  'bjl': 0,
#  'bjm': 0,
#  'bjn': 0,
#  'bjo': 0,
#  'bjp': 0,
#  'bjq': 0,
#  'bjr': 0,
#  'bjs': 0,
#  'bjt': 0,
#  'bju': 0,
#  'bjv': 0,
#  'bjw': 0,
#  'bjx': 0,
#  'bjy': 0,
#  'bjz': 0,
#  'bj ': 0,
#  'bka': 0,
#  ...}

# %% [markdown]
# Create a variable to determine the most common combination of letters.

# %%
mostCommonCombo = max(threeletterdict, key=threeletterdict.get)
print(mostCommonCombo)
# Out:
#  th

# %%
threeletterdict[' th']
# Out:
# 2778

# %% [markdown]
# Use space and t as the inital letters for the new random string, threes, since they are the start of the most common combination. wt turns threeLetterWeights dict into a list. The for loop appends the weighted randon letter output of the nextc variable to the threes string.

# %%
threes = ' t'

# Do the following 998 times.
for i in range(1, 999):
    
    wt = threeLetterWeights[threes[-2]]
    wt = wt[threes[-1]]
    # Turn wt into a list, ordered by chars.
    wt = [wt[c] for c in chars]
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    threes = threes + nextc

# %%
threes
# Out:
# ' the makedishe for he hat goodyartleas couddyal rethen thery vound to youldniff pland lad ad all of thing ther the ou cheagergetthey hatifeellon and inspone calicamed by herfuldly fraceirs of firumbegining equit tatworyphoestrined thin to al said thing dre was alobbir ace prounice so nowelictrewthis exce whento if come loody ableing firse on withe the bers shempow dorts vidleadvid of the he st in al ove thadful nothe sh thouten ittre quithindlegand read as yest gaid armon he feree the sat it nonexed ould alithe we for coultolice jurne arrummeas of turit was the put he us gremealkin in mocking pood ned rou onathence dis se theight isked no hat wely wouted grown to severease the way yourtled tay ther pildriecaremared resy ch wit yous ords the anythe dowlice reftearg or dreme sat cat gut lit lown turead to yould do aturemet she at re to say therpinwhing the justim of it to gry proyes the dowend itivedo pat howning alith youll thery ch he papt goargolitens nobt of thave lover it youshatenl'

# %% [markdown]
# Confirm that threes has 1000 characters.

# %%
print(len(threes))
# Out:
# 1000

# %% [markdown]
# <h2 style="color: rgb(0, 133, 202);">Exercise 2</h2>

# %% [markdown]
# Explain why the log of zero is undefined.
#
# <hr style="border-top: 1px solid rgb(0, 0, 0);" />

# %% [markdown]
# The log of $ 0 $ to 2 implies that there is a number, $ x $, such that
#
#
# $$
# 2^{x} = 0
# $$
#
#
# It is impossible to raise two to any power to equal zero.
#
#
# If $x = 0$, then $2^{0} = 1$.
#
# If $x > 0$, then $2^{x} \rightarrow \infty $ as $ x \rightarrow \infty $ and $2^{x} > 1$.
#
# Finally, if $x < 0$, then
#
# $$2^{x} = \dfrac{1}{2^{-x}}$$
#
# Since in this case $-x > 0$, we can say that
#
# $$\dfrac{1}{2^{-x}} > 0\\
# \Rightarrow 2^{x} > 0
# $$
#
# Since $$\{0\}\cup\{x > 0\}\cup\{x < 0\} = \mathbb{R}$$ we can show that for all $x \in \mathbb{R}$,
#
# $$
# 2^{x} > 0
# $$
#
# This implies that $2^{x} \neq 0$ for any value $x \in \mathbb{R}$. Therefore, $\log_{2}{0}$ is not defined.

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = []
for i in np.arange(0.01, 10, 0.01):
    x.append(i)

y = []
for n in np.arange(0.01, 10, 0.01):
    y.append(math.log2(n))

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('$y = log_{2}{x}$')
plt.title('Plot of $y = log_{2}{x}$')
plt.grid()
plt.show()
